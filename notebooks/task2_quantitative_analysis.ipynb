# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# Add project root directory to Python path
from src.data_loader import load_and_clean_stock_data
aapl_df = load_and_clean_stock_data("../data/raw/AAPL.csv")

amzn_df = load_and_clean_stock_data("../data/raw/AMZN.csv")

goog_df = load_and_clean_stock_data("../data/raw/GOOG.csv")

meta_df = load_and_clean_stock_data("../data/raw/META.csv")

nvda_df = load_and_clean_stock_data("../data/raw/NVDA.csv")

# %%
#Import technical indcator Function in Notebook
import sys
import os

sys.path.append(os.path.abspath(".."))

from src.data_loader import load_and_clean_stock_data
from src.indicators import add_indicators

# %%
#Load All Company Datasets
companies = {
    "AAPL": "../data/raw/AAPL.csv",
    "AMZN": "../data/raw/AMZN.csv",
    "GOOG": "../data/raw/GOOG.csv",
    "META": "../data/raw/META.csv",
    "NVDA": "../data/raw/NVDA.csv"
}

datasets = {}

for company, path in companies.items():
    datasets[company] = load_and_clean_stock_data(path)

# %%
#Apply Indicators to ALL Companies
for company in datasets:

    datasets[company] = add_indicators(datasets[company])

# %%
#Verify Indicators Added for Apple
datasets["AAPL"][[
    'Close',
    'SMA_20',
    'EMA_20',
    'RSI',
    'MACD'
]].tail()
# Out:
#            Close      SMA_20      EMA_20        RSI      MACD
# 3769  191.788757  191.856618  191.510231  54.672784  2.633141
# 3770  191.243912  192.018094  191.484867  53.090049  2.304751
# 3771  191.342972  192.154308  191.471353  53.354446  2.029104
# 3772  191.768951  192.362839  191.499696  54.540999  1.823998
# 3773  190.728775  192.490633  191.426275  51.121347  1.559539

# %%
#Verify Indicators Added for Amazon
datasets["AMZN"][[
    'Close',
    'SMA_20',
    'EMA_20',
    'RSI',
    'MACD'
]].tail()
# Out:
#            Close      SMA_20      EMA_20        RSI      MACD
# 3769  153.419998  148.578999  148.860492  64.115558  3.135958
# 3770  153.410004  148.863000  149.293779  64.085644  3.118650
# 3771  153.339996  149.178500  149.679133  63.860893  3.063965
# 3772  153.380005  149.531499  150.031597  63.938728  2.989395
# 3773  151.940002  149.824000  150.213350  59.012257  2.782032

# %%
#Verify Indicators Added for Google
datasets["GOOG"][[
    'Close',
    'SMA_20',
    'EMA_20',
    'RSI',
    'MACD'
]].tail()
# Out:
#            Close      SMA_20      EMA_20        RSI      MACD
# 3769  141.750000  135.009596  135.854576  64.953309  1.412015
# 3770  141.849304  135.246477  136.425503  65.115870  1.706565
# 3771  140.478683  135.386520  136.811520  60.916026  1.808553
# 3772  140.319748  135.628861  137.145637  60.429303  1.855168
# 3773  139.972137  135.976979  137.414827  59.313063  1.842820

# %%
#Verify Indicators Added for META
datasets["META"][[
    'Close',
    'SMA_20',
    'EMA_20',
    'RSI',
    'MACD'
]].tail()
# Out:
#            Close      SMA_20      EMA_20        RSI      MACD
# 2918  351.224823  332.302945  335.581703  67.333885  6.945367
# 2919  352.655975  333.303278  337.207824  68.187000  7.436800
# 2920  355.637543  334.239505  338.963036  69.947874  7.974921
# 2921  356.124634  335.537503  340.597473  70.237702  8.344500
# 2922  351.791290  336.869788  341.663551  64.296803  8.193282

# %%
#Verify Indicators Added for NVDA
datasets["NVDA"][[
    'Close',
    'SMA_20',
    'EMA_20',
    'RSI',
    'MACD'
]].tail()
# Out:
#           Close     SMA_20     EMA_20        RSI      MACD
# 3769  48.805527  47.706983  48.024644  55.352119  0.634352
# 3770  49.254299  47.759019  48.141754  57.245971  0.655689
# 3771  49.392231  47.838989  48.260847  57.837928  0.675937
# 3772  49.497185  47.908266  48.378593  58.310919  0.692470
# 3773  49.497185  48.046003  48.485126  58.310919  0.697532

# %%
#Visualization for AAPL Price + Moving Averages
import matplotlib.pyplot as plt

aapl = datasets["AAPL"]

plt.figure(figsize=(14,7))

plt.plot(aapl['Close'], label='Close Price')
plt.plot(aapl['SMA_20'], label='SMA 20')
plt.plot(aapl['EMA_20'], label='EMA 20')

plt.title("AAPL Price with SMA and EMA")
plt.legend()

plt.show()

# %%
#Visualization for AMAZON Price + Moving Averages
import matplotlib.pyplot as plt

amzn = datasets["AMZN"]

plt.figure(figsize=(14,7))

plt.plot(amzn['Close'], label='Close Price')
plt.plot(amzn['SMA_20'], label='SMA 20')
plt.plot(amzn['EMA_20'], label='EMA 20')

plt.title("Amazon Price with SMA and EMA")
plt.legend()

plt.show()

# %%
#Visualization for GOOGle Price + Moving Averages
import matplotlib.pyplot as plt

goog = datasets["GOOG"]

plt.figure(figsize=(14,7))

plt.plot(goog['Close'], label='Close Price')
plt.plot(goog['SMA_20'], label='SMA 20')
plt.plot(goog['EMA_20'], label='EMA 20')

plt.title("Google Price with SMA and EMA")
plt.legend()

plt.show()

# %%
#Visualization for META Price + Moving Averages
import matplotlib.pyplot as plt

meta = datasets["META"]

plt.figure(figsize=(14,7))

plt.plot(meta['Close'], label='Close Price')
plt.plot(meta['SMA_20'], label='SMA 20')
plt.plot(meta['EMA_20'], label='EMA 20')

plt.title("META Price with SMA and EMA")
plt.legend()

plt.show()

# %%
#Visualization for NVDA Price + Moving Averages
import matplotlib.pyplot as plt

nvda = datasets["NVDA"]

plt.figure(figsize=(14,7))

plt.plot(nvda['Close'], label='Close Price')
plt.plot(nvda['SMA_20'], label='SMA 20')
plt.plot(nvda['EMA_20'], label='EMA 20')

plt.title("NVDA Price with SMA and EMA")
plt.legend()

plt.show()
